# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Знакомство-с-данными" data-toc-modified-id="Знакомство-с-данными-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Знакомство с данными</a></span></li><li><span><a href="#Ресемплирование" data-toc-modified-id="Ресемплирование-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Ресемплирование</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Выделение-тренда-и-сезонности" data-toc-modified-id="Выделение-тренда-и-сезонности-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выделение тренда и сезонности</a></span></li><li><span><a href="#Создание-признаков" data-toc-modified-id="Создание-признаков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Создание признаков</a></span><ul class="toc-item"><li><span><a href="#Календарные-признаки-(англ.-calendar-features)" data-toc-modified-id="Календарные-признаки-(англ.-calendar-features)-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Календарные признаки (англ. calendar features)</a></span></li><li><span><a href="#«Отстающие-значения»-(англ.-lag-features)" data-toc-modified-id="«Отстающие-значения»-(англ.-lag-features)-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>«Отстающие значения» (англ. lag features)</a></span></li><li><span><a href="#Скользящее-среднее" data-toc-modified-id="Скользящее-среднее-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Скользящее среднее</a></span></li></ul></li><li><span><a href="#Подготовка-выборок-данных" data-toc-modified-id="Подготовка-выборок-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Подготовка выборок данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#LGBMRegressor" data-toc-modified-id="LGBMRegressor-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>LGBMRegressor</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Проверка-на-адекватность" data-toc-modified-id="Проверка-на-адекватность-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка на адекватность</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импорт библиотек

# %%
# Импорт библиотек.
import lightgbm as lgb
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import warnings

# Импорт модулей IPython.
from IPython.display import display_html
from IPython.display import display, HTML
from IPython.display import display, Math, Latex

# Импорт модулей статистики.
from scipy import stats
from statsmodels.iolib.table import SimpleTable
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

from numpy.random import RandomState
# from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score,TimeSeriesSplit 

# Импорт моделей
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# метрик
from sklearn.metrics import mean_squared_error,mean_absolute_error, make_scorer,r2_score

pd.set_option('display.max_columns', None)         # Снимем ограничение на количество показываемых столбцов
pd.options.mode.chained_assignment = None          # Скрываем предупреждение при масшатбировании
warnings.filterwarnings('ignore')                  # Игнорируем предупреждения

# %% [markdown]
# ### Загрузка данных

# %%
try:
    taxi_data = pd.read_csv('/datasets/taxi.csv',sep=',',index_col=[0],  parse_dates=[0])
    taxi_data.sort_index(inplace=True) 
    
except:
    taxi_data = pd.read_csv('taxi.csv',sep=',',index_col=[0], parse_dates=[0])
    taxi_data.sort_index(inplace=True)

# %% [markdown]
# ### Знакомство с данными

# %%
def data_info (df):
    '''
    Сводка по данным
    '''
    display(df.head(10))
    print('Общая информация:')
    display(df.info())
    print('Общая статистика:')
    display(df.describe())
    print('Дубликаты:')
    display(df.duplicated().sum())
    display(df[df.duplicated()])
    print('Соблюдение хронологического порядка:')
    display(df.index.is_monotonic)

# %%
data_info(taxi_data)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# 2018-03-01 00:50:00          21
# 2018-03-01 01:00:00           7
# 2018-03-01 01:10:00           5
# 2018-03-01 01:20:00          17
# 2018-03-01 01:30:00          12
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB
# None
# Общая статистика:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000
# Дубликаты:
# 26415
# ...

# %% [markdown]
# ***Вывод:*** <br>
#
# *В представленных данных имеются:*
# * Количество заказов в столбце `num_orders`, распределенных на десятиминутных временных промежутках.
# * Минимальное количество заказов за 10-ти минутный интервал - 0, а максимальное - 119.
# * Временной интервал с 01 марта по 31 августа 2018г.
# * В данных пропусков нет.

# %% [markdown]
# ### Ресемплирование

# %% [markdown]
# *По условию задания заказчику требуется прогноз количества заказываемых такси на следующий час. В связи с этим требуется изменить интервал временного ряда с 10 минут, в представленном виде, на 1 час.*

# %%
taxi_data = taxi_data.resample('1H').sum()

# %%
taxi_data
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# ...                         ...
# 2018-08-31 19:00:00         136
# 2018-08-31 20:00:00         154
# 2018-08-31 21:00:00         159
# 2018-08-31 22:00:00         223
# 2018-08-31 23:00:00         205
#
# [4416 rows x 1 columns]

# %%
taxi_data.plot(figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# ***Вывод:***<br>
#
# - *В ходе работы над данными было произведено ресемплирование с указанием целевого интервала и построен график. Данные нуждаются в дальнейшем анализе для улучшения интерпретируемости.*
# - *График приближённо похож на стационарный, хотя в конце наблюдается небольшое увеличение среднего значения и дисперсии*

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Выделение тренда и сезонности

# %%
def trend_n_seasonality (data):
    
    decomposed = seasonal_decompose(data)
    
    plt.figure(figsize=(10, 8))
    plt.subplot(311)
    
#   Чтобы график корректно отобразился, указываем его 
#   оси ax, равными plt.gca() (англ. get current axis,
#   получить текущие оси)
    
    decomposed.trend.plot(ax=plt.gca())
    plt.title('Trend')
    plt.subplot(312)
    decomposed.seasonal.plot(ax=plt.gca())
    plt.title('Seasonality')
    plt.subplot(313)
    decomposed.resid.plot(ax=plt.gca())
    plt.title('Residuals')
    plt.tight_layout()

# %%
trend_n_seasonality(taxi_data)

# %% [markdown]
# ***Выводы:***<br>
# *По данным в представленном интервале тренд видно, а сезонность нет.* <br>
# *Уменьшим окно данных до одного месяца (возьмём август, как месяц, где отчётливо прослеживается тренд)*

# %%
taxi_data_short_range = taxi_data['2018-08-01':'2018-08-31']
trend_n_seasonality(taxi_data_short_range)

# %% [markdown]
# ***Выводы:*** <br>
# *Тренд так же отчётливо виден на интервале в один месяц* <br>
# *По графику сезонности можно предположить, что сезонность может носить суточный характер* <br>
# *Проверим сезонность, сократив интервал до двух суток, чтобы увидеть предполагаемое повторение сезонности*

# %%
taxi_data_day_range = taxi_data['2018-08-01':'2018-08-03']
trend_n_seasonality(taxi_data_day_range)

# %% [markdown]
# ***Выводы:*** <br>
# *Суточный характер сезонности подтверждается - видны повторяющиеся контуры графика по каждому дню (почему-то чаще вызывают такси ночью)*

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
#     <p>
# Исследование - понятно.<br>
# Инструмент декомпозиции в частности, а графический анализ временных рядов как в принципе - важный этап моделирования рядов.<br> Позволяет увидеть продажи визуально, а это помогает сделать предвариетльные выводы<br>
#
# Хочу озвучить ещё такой момент<br>
# В реальности бизнеса есть все три вида сезонности:<br>
# 1) дневная сезонность -  данные собраны по дням, т.е. будни и выходные имеют разные продажи<br>
# 2) внутрисуточная сезонность: когда продажи утром отличаются от продаж вечером <br>
# 3) месячная сезонность: когда продажи лета и осени - разные.<br><br>
# И если строить прогноз на длительный период времени, то без учёта всех видов сезонности  - не обойтись<br>
# Например: есть в данных восходящий тренд. Но вопрос такой возникает: <br>
# этот подъём действительно за счёт роста компании (чаще всего тренд - это отражение роста компании) или есть ещё влияние месячной сезнности? (летом - продаж в рост, например, и именно этот момент мы наблюдаем в данных)<br>
# Ответ на вопрос - не протой на имеющихся данных - у нас данных меньше года. А это означает, что месячную сезонность нам не просто вычислить адекватно - т.е. не внести в модель корректтировки месяцев(<br>
# Поэтому, я бы дал такой совет:<br>
# на горизонте прогнозирования - несколько часов или дней - можно предположить что у нас тренд.<br>
# А если строить прогноз на несколько недель - вот тут утверждать наличие тренда надо с большой осторожностью))))<br><br>
# Ну, а если вернуться к постановке задаче - построить прогноз на час (очень маленький горизонт), то двух сезонности может и хватить.
# </font></p></div>

# %% [markdown]
# ### Создание признаков

# %% [markdown]
# ####  Календарные признаки (англ. calendar features)

# %%
# Так как данные представлены за не полный год, то нет смысла выделять категории: "год" и "месяц" 
# поскольку их будет не с чем сравнить.

# Создадим признак, в котором хранится день недели как число
taxi_data['dayofweek'] = taxi_data.index.dayofweek

# Создадим признак, в котором хранится номер недели в году как число
taxi_data['weekofyear'] = taxi_data.index.weekofyear

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# Номер недели - на обсуждение, на мой взгляд. А вот час, как фактор - онозначно стоит вносить в модель!

# %% [markdown]
# ####  «Отстающие значения» (англ. lag features)

# %%
# Поскольку по условию задачи требуется предсказать количество заказов такси на следующий час, то 
# нас будет интересовать информация о тренде от часа к часу в течение суток, т.е. за 24 часа.

for hour in range(1, 24):
    taxi_data[f'lag_{hour}'] = taxi_data[taxi_data.columns[0]].shift(hour)

taxi_data
# Out:
#                      num_orders  dayofweek  weekofyear  lag_1  lag_2  lag_3  \
# datetime
# 2018-03-01 00:00:00         124          3           9    NaN    NaN    NaN
# 2018-03-01 01:00:00          85          3           9  124.0    NaN    NaN
# 2018-03-01 02:00:00          71          3           9   85.0  124.0    NaN
# 2018-03-01 03:00:00          66          3           9   71.0   85.0  124.0
# 2018-03-01 04:00:00          43          3           9   66.0   71.0   85.0
# ...                         ...        ...         ...    ...    ...    ...
# 2018-08-31 19:00:00         136          4          35  207.0  217.0  197.0
# 2018-08-31 20:00:00         154          4          35  136.0  207.0  217.0
# 2018-08-31 21:00:00         159          4          35  154.0  136.0  207.0
# 2018-08-31 22:00:00         223          4          35  159.0  154.0  136.0
# 2018-08-31 23:00:00         205          4          35  223.0  159.0  154.0
#
# ...

# %% [markdown]
# #### Скользящее среднее

# %%
# Создадим признак, чтобы модель могла отслеживать суточный тренд.

rolling_mean_size = 24
taxi_data['rolling_mean'] = taxi_data['num_orders'].shift().rolling(rolling_mean_size).mean()

taxi_data
# Out:
#                      num_orders  dayofweek  weekofyear  lag_1  lag_2  lag_3  \
# datetime
# 2018-03-01 00:00:00         124          3           9    NaN    NaN    NaN
# 2018-03-01 01:00:00          85          3           9  124.0    NaN    NaN
# 2018-03-01 02:00:00          71          3           9   85.0  124.0    NaN
# 2018-03-01 03:00:00          66          3           9   71.0   85.0  124.0
# 2018-03-01 04:00:00          43          3           9   66.0   71.0   85.0
# ...                         ...        ...         ...    ...    ...    ...
# 2018-08-31 19:00:00         136          4          35  207.0  217.0  197.0
# 2018-08-31 20:00:00         154          4          35  136.0  207.0  217.0
# 2018-08-31 21:00:00         159          4          35  154.0  136.0  207.0
# 2018-08-31 22:00:00         223          4          35  159.0  154.0  136.0
# 2018-08-31 23:00:00         205          4          35  223.0  159.0  154.0
#
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>Пару строк по фактору лаг и скользящее среднее:<br>
# Lag: его называют ещё параметром авторегрессии. На бытовом уровне его можно понять так: допустим вчера мы собрались с друзьями и не много закусили.... повлияет ли это на сегодняшний настрой на жизнь? Скорее да)))) Так вот с авторегрессией также. Допустим lag=1 - учитывает (для удобства будем считать, что продажи собраны по дням) как вчерашние продажи - вчерашние события - воалияли на сегоняшние.Lag=2: учитывает как позавчерашние продажи влияютна сегодняшние.....<br>
#
# По скользящему среднего:<br>
# Предположим rolling=10 - скользящее среднее. По сути, ищем среднее по 10 точкам, потом следующие 10 точек, и т.д. - это некое подобие тренда будет - средней линии. Т.е. - сглаживание колебаний/выбросов. Это легко увидеть на пределе: допустим длина ряда 100 дней. rolling(100) - это просто одно число - среднее всего ряда. <br>
#
# Поэтому, если выставить сезонности - hour и деньНедели, то дополнительные факторы могут быть такие: лаг =1 (максимум 2), а скользящее среднее = 24 (среднее за сутки). Т.е. начинать с этого. В итоге модель будет приемлемая по точности и не много факторов.. а это значит и для бизнеса будет легче доносить решение)</div

# %%
# Удалим из данных первые сутки, т.к. в вычисленных значениях признаков отсутствуют значения,
# что будет мешать обучению моделей.

taxi_data = taxi_data['2018-03-02':'2018-08-31']

# %% [markdown]
# ### Подготовка выборок данных

# %%
def split_df(df):
    
    '''
    Функция делит данные на обучающую и тестовую выборки 
    посредством train_test_split без перемешивания выборок.
    
    '''
    
    train, test = train_test_split(df, shuffle=False, test_size=0.1) #размер тестовой выборки 10% в соответствии с условием задания
        
    features_train = train.drop(['num_orders'] , axis=1)
    target_train = train['num_orders']
    
    
    features_test = test.drop(['num_orders'] , axis=1)
    target_test = test['num_orders']
    
    


    return features_train,target_train,features_test,target_test,train

# %%
features_train,target_train,features_test,target_test,train = split_df(taxi_data)

# %%
print('Размер обучающей выборки:',features_train.shape)
print('Размер вектора целевого признака обучающей выборки:',target_train.shape[0])
print('Размер тестовой выборки:',features_test.shape)
print('Размер вектора целевого признака тестовой выборки:',target_test.shape[0])
# Out:
# Размер обучающей выборки: (3952, 26)
# Размер вектора целевого признака обучающей выборки: 3952
# Размер тестовой выборки: (440, 26)
# Размер вектора целевого признака тестовой выборки: 440

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# ОК

# %% [markdown]
# ### Вывод

# %% [markdown]
# *Анализ предоставленных данных выявил:*
# - *количество заказов с марта по август имеет устойчивый тренд*
# - *количество заказов имеет выраженную повторяющуюся сезонность в течение дня с пиком заказов в полночь*
# <br>
#
# <br>
#
# *Так же в данные были добавлены:*
# - *Календарные признаки.*
# - *Отстающие значения.*
# - *Скользящее среднее.*
# <br>
# *Было проведено разделение данных на обучающую и тестовые выборки*
# <br>
# <br>
#
# ***Данные готовы для дальнейшего обучения моделей***

# %% [markdown]
# ## Обучение моделей

# %%
# Создадим словарь для записи результатов RMSE моделей
rmse_list = {}

# %%
def grid_search_params (model,params,features,target):
    
    '''
    Принимает на вход название обучаемой модели, набор её параметров, обучающую и тестовую выборки
    Возвращает наилучшие параметры модели при которых целевая метрика RMSE (ошибка) минимальна
    '''

    tscv = TimeSeriesSplit(n_splits=5)
    
    model_grid = GridSearchCV(model,params,cv=tscv, n_jobs=-1,scoring='neg_root_mean_squared_error', verbose=2)
    model_grid.fit(features,target)
    best_params = model_grid.best_params_
    best_score = model_grid.best_score_
    
    return model_grid,best_params,best_score

# %% [markdown]
# ### LinearRegression

# %%
# %%time

model_linreg = LinearRegression()
tscv_lin = TimeSeriesSplit(n_splits=5)

rmse_linreg = cross_val_score(LinearRegression(),
                                          features_train,
                                          target_train,
                                          cv=tscv_lin, scoring='neg_root_mean_squared_error').min()
rmse_linreg = rmse_linreg *(-1)
display(HTML(f"<font color='purple'>RMSE LinearRegression:{rmse_linreg:.3f}</font>"))
# Out:
# <font color='purple'>RMSE LinearRegression:33.402</font>
# CPU times: total: 78.1 ms
# Wall time: 52 ms

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# ОК,
# n_splits , обычно, задают так, чтобы размер валидационной выборки при проведении кросс-валидации примерно совпадал с размером тестовой выборки. Размер тестовой выборки у нас 10%, а размер валидационной равен 1/(n_splits+1) части от обучающей выборки (см. документацию к TimeSeriesSplit). К примеру, если n_splits=2, то размер валидационной равен 1/3 от обучающей выборки, т.е. 1/3*90%=30% от исходной выборки.<br>
# Возможно, что n_splits=8, то 1/9*90%=10%  - будет более точное попадание.

# %%
rmse_list['LinearRegression'] = [rmse_linreg]

# %% [markdown]
# ### RandomForestRegressor

# %%
params_forest = {'max_depth': range(12,16,1),'n_estimators': range(133,137,1)}
model_forest = RandomForestRegressor(random_state=12345)

# %%
# %%time
model_grid_forest,best_params_forest,best_score_forest = grid_search_params(model_forest,params_forest,
                                                                         features_train,target_train)

display(HTML(f"<font color='green'>RMSE RandomForestRegressor: {best_score_forest*(-1):.3f}</font>"))
best_params_forest
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# <font color='green'>RMSE RandomForestRegressor: 26.734</font>
# CPU times: total: 7.45 s
# Wall time: 1min 29s
# {'max_depth': 15, 'n_estimators': 135}

# %%
rmse_list['RandomForestRegressor'] = [best_score_forest*(-1)]

# %% [markdown]
# ### LGBMRegressor

# %%
model_lgbm = LGBMRegressor()
params_lgbm = {
          'objective': ['regression'],
          'max_depth': range(6,8,1),
          'learning_rate':np.arange(0.039,0.041,0.001),
          "boosting_type": ['gbdt'],
          "metric": ['rmse'],
          "verbosity": [-1],
          'random_state': [12345],
          'n_estimators': range(448,450,1),        
    }

# %%
# %%time
model_grid_lgbm,best_params_lgbm,best_score_lgbm = grid_search_params(model_lgbm,params_lgbm,
                                                                   features_train,target_train)

display(HTML(f"<font color='blue'>RMSE LGBMRegressor:\
{best_score_lgbm*(-1):.3f}</font>"))
best_params_lgbm
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# <font color='blue'>RMSE LGBMRegressor:26.014</font>
# CPU times: total: 4.97 s
# Wall time: 9.9 s
# {'boosting_type': 'gbdt',
#  'learning_rate': 0.04,
#  'max_depth': 7,
#  'metric': 'rmse',
#  'n_estimators': 449,
#  'objective': 'regression',
#  'random_state': 12345,
#  'verbosity': -1}

# %%
rmse_list['LGBMRegressor'] = [best_score_lgbm*(-1)]

# %%
rmse_score = pd.DataFrame.from_dict(data=rmse_list, columns=[
    'RMSE' 
    ],
    orient='index')

rmse_score
# Out:
#                             RMSE
# LinearRegression       33.402019
# RandomForestRegressor  26.733573
# LGBMRegressor          26.014021

# %% [markdown]
# ### Вывод

# %% [markdown]
# *Лучший результат на обучающей выборке показала модель LGBMRegressor с минимальной метрикой ошибки RMSE*

# %% [markdown]
# ## Тестирование

# %%
# %%time


# Обучим модель на ранее полученных параметрах для минимального RMSE и проверим её работу на тестовой выборке
model_best = LGBMRegressor(
    
    boosting_type ='gbdt',
    learning_rate = 0.036,        #Немного скорректируем исходный LR для улучшения результатов
    max_depth = 7,
    metric = 'rmse',
    n_estimators = 449,
    objective = 'regression',
    random_state = 12345,
    verbosity = -1,
    force_row_wise = True,
)
model_best.fit(features_train, target_train)

predicted_best = model_best.predict(features_test)
rmse_best = (mean_squared_error(target_test, predicted_best)) ** 0.5

display(HTML(f"<font color='red'>RMSE LGBMRegressor на тестовой выборке:{rmse_best:.3f}</font>"))
# Out:
# <font color='red'>RMSE LGBMRegressor на тестовой выборке:43.587</font>
# CPU times: total: 6.95 s
# Wall time: 1.13 s

# %%
predicted_data = pd.DataFrame(predicted_best).round().astype(int)
target_data = pd.DataFrame(target_test)
comparison_data = target_data.reset_index().join(predicted_data)
comparison_data = comparison_data.rename(columns={"num_orders": "target", 0: "predicted"}, errors="raise")
comparison_data = comparison_data.set_index('datetime')

plt.figure(figsize=(10, 6))
rc = {"axes.grid" : True}
plt.rcParams.update(rc)

line_up = plt.plot(comparison_data['2018-08-29':'2018-08-31'], label='Line 1')
line_down = plt.plot(comparison_data['2018-08-29':'2018-08-31'], label='Line 2')
plt.legend([line_up, line_down], ['Line Up', 'Line Down'])


red_patch_1 = mpatches.Patch(color='red', label='Predict_data')
red_patch_2 = mpatches.Patch(color='green', label='Target_data')
plt.legend(handles=[red_patch_1,red_patch_2])

plt.title("LGBMRegressor - Test_data comparison")
# Out:
# Text(0.5, 1.0, 'LGBMRegressor - Test_data comparison')

# %% [markdown]
# ***Вывод:*** <br>
# *Модель соответствует условию задачи - RMSE меньше 48*

# %% [markdown]
# ## Проверка на адекватность

# %%
# %%time
dummy_uniform = DummyRegressor(strategy='mean').fit(features_train, target_train)
dummy_pred = dummy_uniform.predict(features_test)
rmse_dummy = (mean_squared_error(target_test, dummy_pred)) ** 0.5

display(HTML(f"<font color='grey'>RMSE DummyRegressor на тестовой выборке:{rmse_dummy:.3f}</font>"))

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# ОК, Михаил, с модельной частью тебе удалось справиться хорошо!<br>
# Видно, что этот скил уже достаточно сильный.<br>
# Метрика - ОК. Но не понятно, если честно, а хороша ли эта модель в плане предсказания? Для этого лучше построить дополнительно график (чуть ниженаписал об этом).<br>
#
# И если сутейно рассуждать, то временные ряды стоят особняком во всём курсе, я бы сказал. Тут чуть иная модельная философия, на мой взгляд. Имменно поэтому позволял себе оставлять большие рассуждения, чтобы как-то раскрыть её особенности.<br>
#
# Оставил несколько комментариев в тексте - готов буду ответить на твои вопросы!<br>
# <font color='red'>
# Также попрошу вот что:<br>
# Выведи, пожалуйста графики факт/предсказанное на одном рисунке (обычный линейный график). Чтобы увидеть где основные не "попадалки" модели. Это один из важнейших инструментов анализа результатов моделирования временных рядов.<br>
# Лучше выбрать масштаб, скажем, несколько дней, чтобы увиеть можо было и сравнить каждый час.<br>
# <font color='green'>
# Спасибо)<BR>
# БУДУ ЖДАТЬ КОММЕНТАРИЕВ</div>

# %% [markdown]
# <div class="alert alert-info" style="border-color: blue; border-radius: 5px">
#     <p><u><b> КОММЕНТАРИЙ СТУДЕНТА</b></u></p>
# <br>
#     График добавил<br>
#     В целом на графике видно, что модель не очень хорошо справляется с пиками (что в принципе ожидаемо), и имеет небольшой сдвиг в предсказаниях. В остальном работу модели можно считать удовлетворительной.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА 2</b></u></p>
# Привет, Михаил!<br>
# ОК, увидел твои изменения. Надо признать, что резкие изменения продаж не просто спрогнозировать(... т.к. в эти дни были факторы продаж, о которых в истории не было сказано. Или по другому: в эти дни клиенты вели себя по другому, чем раньше. В факторах, которые мы заложили, этой информации нет. поэтому и не угадываем( тут надо смириться. И провести анализ план-факт: выяснить причины расхождения прогноза и фактически продаж и, если надо, скорректировать модель на найденную причину. Т.е. включить причину, как фактор.<br>
#
# Тут много ещё что хотелось бы сказать по самой теме...<br>
# Если будет возможность тебе однозначно интересно посмотреть разные практические истории вот здесь:<br>
# https://ibf.org/knowledge - заморский институт бизнес-прогнозирования.<br>
# Там и статьи можно накопать, и методы посмомтерть...<br>
#
# Есть классический труд (он НЕ ML, а исключительно на эксель). Но для понимания сути временных рядов - то, что надо:<br>
# УИЧЕРН "Бизнес-прогнозирование"<br>
#
# Идеологически по системе прогнозирования, интересно почитать<br>
# ТОМАС УОЛЛАС, Р. СТАЛЬ "планирование продаж и операций" SO&P<br><br>
#
# Спасибо за проект)<br>
# УСПЕШНОГО ДАЛЬНЕЙШЕГО ОБЧЕНИЯ!</div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Вывод

# %% [markdown]
# ***В ходе работы были обработаны и проанализированы данные о заказах такси*** <br>
# ***Среди рассмотренных моделей наилучшие предсказания с точки зрения минимизации ошибки показала модель градиентного бустинга Light GBM.*** <br>
# ***На тестовой выборке показатель RMSE модели составил - 43.587, что меньше поставленного в задаче максимального - 48 и значительно меньше показателя RMSE случайной модели*** <br>

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# Хотел бы оставить несколько идей для твоих будущих проектов в этой обоасти<br>
#
# На мой взгляд, в этой теме (временные ряды) главное - необходимо чувствовать исходный ряд продаж, с точки зрения бизнеса, и уже только потом подбирать к нему модели. Каждое колебание временного ряда - это деньги для бизнеса (если говорим что заказчик бизнесовый) и за "трепетами" данных прячутся разные семейства причин. И именно знание их помогут строить хорошие прогнозы..<br>.
# Леса, бустинги, регрессии.... могут подобрать хорошие модели на старых данных. Но иногда, как прогноз эти, модели могут оказаться пустышками - не интересными бизнесу. <br>  <br>
# Поэтому, от себя позволю добавить несколько идей:<br>
# Очень часто ищут "волшебную таблетку" или "кнопку". Нажал и само всё построилось с высокой точностью<br>
# Но такого никогода не будет)))<br>
# И причиной тому: модели нужно подсказать причины, по которым происходит колебания продаж (временного ряда): понимать причины колебаний треда, понимать аномалии, учитывать акционные продажи, видеть действия конкурентов , закладывать их в модель и т.д. <br><br>
# В общем, всё как обычно - три группы факторов: <br>
# 1)внешние факторы (например выручка такси-компании зависит от количества машин на линии),<br>
# 2)есть факторы внутри самих данных (Вы использовали как раз поняти лаг, сезонности), <br>
# 3)есть параметры самих моделей (то, что обычно используется при моделировании леса или деревьев).<br><br>
#
# Ещё важно иметь ввиду горизонт прогноза: на кокой период строить прогноз нужно  - на час вперёд, на неделю, на месяц.<br>
# Это также накладывает ограничения на подбор моделей<br>
# Я бы рекомендовал Вам составить для себя матрицу  в разрезе: <br>
# а)есть тренд/нет тренда; <br>
# б)еть сезоннотсь/нет сезонности; <br>
# в)какой горизонт прогноза требуется; <br>
# г) есть ли у нас дополнительные факторы для модей<br>
# На пересечении знаний о моделях легко будет подобрать адкватную модель.
# Не все задачи прогнозирования временных рядов можно хорошо решить лесом и еже с ним на основе знаний только факторов ряда... Они хорошо подойдут для коротких горизонтов прогнозирования.... А если горизонт чуть больше: недели, месяцы... то тут надо подключать понимания фаткоров продаж самого бизнеса.</div>
